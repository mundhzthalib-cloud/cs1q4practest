# %% [markdown]
# <a href="https://colab.research.google.com/github/mundhzthalib-cloud/cs1q4practest/blob/main/cs1q4practest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Welcome to the Student Score Analyzer!")

name = input("Please Enter Your Name: ")

score1 = float(input("Enter Quiz Score 1: "))
score2 = float(input("Enter Quiz Score 2: "))
score3 = float(input("Enter Quiz Score 3: "))

average = (score1 + score2 + score3) / 3
if average >= 70:
  status = "PASSED"
else:
  status = "FAILED"
print("Calculating Results... ")
print(f"Hello, {name}!")
print(f"Your Average is: {average}")
print(f"Status: {status}")
# Out:
# Welcome to the Student Score Analyzer!
# Please Enter Your Name: 0
# Enter Quiz Score 1: 90
# Enter Quiz Score 2: 90
# Enter Quiz Score 3: 90
# Calculating Results...
# Hello, 0!
# Your Average is: 90.0
# Status: PASSED
